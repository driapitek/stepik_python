# %% [markdown]
# #Основы

# %%
a = 5
b = 7
print(a+b)

# %%
name = input()
print('Hello', name)
# Out:
# Vasya
# Hello Vasya

# %% [markdown]
# Функция `input()` нужна для ввода

# %%
X = int(input())
Y = int(input())
print(X*60 + Y)
# Out:
# 30
# 20
# 1820

# %% [markdown]
# Коля каждый день ложится спать ровно в полночь и недавно узнал, что оптимальное время для его сна составляет X минут. Коля хочет поставить себе будильник так, чтобы он прозвенел ровно через X минут после полуночи, однако для этого необходимо указать время сигнала в формате часы, минуты. Помогите Коле определить, на какое время завести будильник.

# %%
X = int(input())
print(X//60)
print(X%60)
# Out:
# 800
# 13
# 20

# %% [markdown]
# Катя узнала, что ей для сна надо X минут. В отличие от Коли, Катя ложится спать после полуночи в H часов и M минут. Помогите Кате определить, на какое время ей поставить будильник, чтобы он прозвенел ровно через X минут после того, как она ляжет спать.
#
# На стандартный ввод, каждое в своей строке, подаются значения X, H и M. Гарантируется, что Катя должна проснуться в тот же день, что и заснуть. Программа должна выводить время, на которое нужно поставить будильник: в первой строке часы, во второй — минуты.

# %%
X = int(input())
H = int(input())
M = int(input())
print((H*60 + M + X)//60)
print((H*60 + M + X)%60)
# Out:
# 475
# 1
# 55
# 9
# 50

# %% [markdown]
# # Логические значения

# %%
a = int(input())
print(a > 0)

# %% [markdown]
# [Вот тут приоритет операторов Питона](https://docs.python.org/3/reference/expressions.html#operator-precedence)

# %% [markdown]
# Всё как всегда с логическими операторами

# %%
a = int(input())
print(10 <= a < 100)
# Out:
# 1000
# False

# %%
x1, x2, x3 = False, True, False
not x1 or x2 and x3
# Out:
# True

# %% [markdown]
# Как вычислялось это выражение наибольший приоритет **not** далее **and**, потом **or**

# %%
True or x2 and x3
True or False
# Out:
# True

# %% [markdown]
# то есть это эквивалентно этому выражению

# %%
(not x1 or x2 and x3) == (True or False) == (True or x2 and x3)
# Out:
# True

# %% [markdown]
# Можем изменить порядок скобочками. Теперь идёт **not** далее **or**, потом **and**

# %%
((not x1) or x2) and x3
# Out:
# False

# %% [markdown]
# ## Задания
# ### 1.
# Расставьте скобки в выражении
#
# a **and** b **or** **not** a **and** **not** b
#
# в соответствии с порядком вычисления выражения (приоритетом операций). Всего потребуется 5 пар скобок (внешние скобки входят в их число).
#  ((a and b) or ((not a) and (not b)))

# %% [markdown]
# ### 2.
# Выполните код в интерпретаторе Python 3 и вставьте в поле ответа результат вычисления. Постарайтесь разобраться, почему интерпретатор выдал именно такой ответ. Помните, что любые арифметические операции выше по приоритету операций сравнения и логических операторов.

# %%
x = 5
y = 10
y > x * x or y >= 2 * x and x < y
# Out:
# True

# %% [markdown]
# Потому что это эквивалентно выражению, согласно порядку операторов

# %%
(y > (x * x)) or ((y >= (2 * x)) and (x < y))
(10 > 25) or ((10 >= 10) and (5 < 10))
False or True and True
False or True
# Out:
# True

# %% [markdown]
# [Шпаргалка по логическим операторам в Python](https://stepik.org/lesson/2413/step/8?discussion=354330&unit=930)

# %% [markdown]
# ### 3.
# Найдите результат выражения для заданных значений a и b. Учитывайте регистр символов при ответе.

# %%
a = True
b = False
a and b or not a and not b
# Out:
# False

# %% [markdown]
# Это эквивалентно выражению:

# %%
(a and b) or ((not a) and (not b))
(True and False) or (False and True)
False or False
# Out:
# False

# %% [markdown]
# # Условия If, else

# %% [markdown]
# Условия задаются таким вот синтаксисом

# %%
x = int(input())
if x % 2 == 0 :
  print('Четное')
else:
  print('Нечетное')
# Out:
# 2
# Четное

# %% [markdown]
# В общем случае задание условия выглядит следующим образом:
#
# **if** условие1:
#
#   *блок действия1*
#
# **elif** условие2:
#
#   *блок действия2*
#
# **else**:
#
#   *блок действия3*

# %% [markdown]
# Например задача. Есть два числа, найти наибольшее из этих чисел
#
# Интуитивный подход выглядит так:

# %%
x = int(input())
y = int(input())
if x == y:
  print('Числа равны')
elif x > y:
  print(x)
else:
  print(y)
# Out:
# 4
# 0
# 4

# %% [markdown]
# Есть такой подход, который может быть обобщен на большое количество чисел. А ещё он короче. Мы вводим ещё одну переменную --- в неё будет присваиваться максимум, и всегда мы будем выводить её.

# %%
x = int(input())
y = int(input())
max = x
if y > max:
  max = y
  print(max)
# Out:
# 4
# 8
# 8

# %% [markdown]
# Реализуем программу, которая делит одно число на другое, если это возможно

# %%
a = int(input())
b = int(input())
if b != 0:
  print(a/b)
else:
  print('Делить на ноль нельзя')
# Out:
# 9
# 0
# Делить на ноль нельзя

# %% [markdown]
# Модифицируем программу, если деление невозможно, попросим ввести пользователя ещё раз число

# %%
a = int(input())
b = int(input())
if b != 0:
  print(a/b)
else:
  print('Делить на ноль нельзя, попробуйте ввести другое число')
  b = int(input())
  if b != 0:
    print(a/b)
  else:
    print('Вы снова ввели ноль, я не умею на него делить')
# Out:
# 8
# 0
# Делить на ноль нельзя, попробуйте ввести другое число
# 0
# Вы пытались ;(

# %% [markdown]
# ## Задача

# %% [markdown]
# Из передачи “Здоровье” Аня узнала, что рекомендуется спать хотя бы A часов в сутки, но пересыпать тоже вредно и не стоит спать более B часов. Сейчас Аня спит H часов в сутки. Если режим сна Ани удовлетворяет рекомендациям передачи “Здоровье”, выведите “Это нормально”. Если Аня спит менее A часов, выведите “Недосып”, если же более B часов, то выведите “Пересып”.

# %%
a = int(input())
b = int(input())
h = int(input())
if a <= b:
  if h < a:
    print('Недосып')
  elif h <= b:
    print('Это нормально')
  else:
    print('Пересып')
# Out:
# 7
# 7
# 7
# Это нормально

# %% [markdown]
# ## Задача
#
# Требуется определить, является ли данный год високосным.
#
# Напомним, что високосными годами считаются те годы, порядковый номер которых либо кратен 4, но при этом не кратен 100, либо кратен 400 (например, 2000-й год являлся високосным, а 2100-й будет невисокосным годом).
#
# Программа должна корректно работать на числах 1900≤n≤3000.
#
# Выведите "Високосный" в случае, если считанный год является високосным и "Обычный" в обратном случае (не забывайте проверять регистр выводимых программой символов).

# %%
n = int(input())
if (n % 4 == 0 and n % 100 != 0) or (n % 400 == 0):
  print('Високосный')
else:
  print('Обычный')
# Out:
# 2000
# Високосный

# %% [markdown]
# # Строки

# %% [markdown]
# Конкатенация

# %%
'abs' + "fge"
# Out:
# 'absfge'

# %% [markdown]
# Мультипликация

# %%
'abs' * 3
# Out:
# 'absabsabs'

# %% [markdown]
# Длина строки

# %%
len('sdfdsfsf')
# Out:
# 8

# %% [markdown]
# Сравнение строк. Строка считается больше, если лексикографически она идёт раньше

# %%
'abs' == "abs"
# Out:
# True

# %%
'abs' < "ab"
# Out:
# False

# %%
'abs' > "ab"

# %%
"239" < "30"
# Out:
# True

# %% [markdown]
# Ещё примеры конкатенации

# %%
a = 'sntrin'
b = 'trad'
print(a, b)
print(a + b)
print(a +'\n'+ b)
"123" + "42"
# Out:
# sntrin trad
# sntrintrad
# sntrin
# trad
# '12342'

# %% [markdown]
# ## Задачи
#
# В то далёкое время, когда Паша ходил в школу, ему очень не нравилась формула Герона для вычисления площади треугольника, так как казалась слишком сложной. В один прекрасный момент Павел решил избавить всех школьников от страданий и написать и распространить по школам программу, вычисляющую площадь треугольника по трём сторонам.
#
# Одна проблема: так как эта формула не нравилась Павлу, он её не запомнил. Помогите ему завершить доброе дело и напишите программу, вычисляющую площадь треугольника по переданным длинам трёх его сторон по формуле Герона:
# $$S = \sqrt{p(p−a)(p−b)(p−c)}$$
# где  $p=\frac{a+b+c}{2}$ полупериметр треугольника. На вход программе подаются целые числа, выводом программы должно являться вещественное число, соответствующее площади треугольника.

# %%
import math
a = int(input())
b = int(input())
c = int(input())
p = (a+b+c)/2
print(math.sqrt(p*(p-a)*(p-b)*(p-c)))
# Out:
# 3
# 4
# 5
# 6.0

# %% [markdown]
# Напишите программу, принимающую на вход целое число, которая выводит True, если переданное значение попадает в интервал $(−15,12]∪(14,17)∪[19,+∞)$ и False в противном случае (регистр символов имеет значение).
#
# Обратите внимание на разные скобки, используемые для обозначения интервалов. В задании используются полуоткрытые и открытые интервалы. Подробнее про это вы можете прочитать, например, на википедии (полуинтервал, промежуток).

# %%
a = int(input())
if (a > -15 and a <=12) or (a > 14 and a < 17) or (a >= 19):
  print('True')
else:
  print('False')
# Out:
# 23
# True

# %% [markdown]
# Вот ещё интересный вариант

# %%
a = int(input())
print((-15 < a <= 12) or (14 < a < 17) or (19 <= a))
# Out:
# -20
# False

# %% [markdown]
# Напишите простой калькулятор, который считывает с пользовательского ввода три строки: первое число, второе число и операцию, после чего применяет операцию к введённым числам ("первое число" "операция" "второе число") и выводит результат на экран.
#
# Поддерживаемые операции: +, -, /, *, mod, pow, div, где
# mod — это взятие остатка от деления,
# pow — возведение в степень,
# div — целочисленное деление.
#
# Если выполняется деление и второе число равно 0, необходимо выводить строку "Деление на 0!".
#
# Обратите внимание, что на вход программе приходят вещественные числа.

# %%
a = float(input())
b = float(input())
operand = str(input())
if operand == '+':
  print(a+b)
elif operand == '-':
  print(a-b)
elif operand == '/':
  if b == 0:
    print("Деление на 0!")
  else:
    print(a/b)
elif operand == '*':
  print(a*b)
elif operand == 'mod':
   if b == 0:
    print("Деление на 0!")
   else:
    print(a%b)
elif operand == 'div':
   if b == 0:
    print("Деление на 0!")
   else:
    print(a//b)
elif operand == 'pow':
  print(a**b)
# Out:
# 5
# 10
# /
# 0.5

# %% [markdown]
# Жители страны Малевии часто экспериментируют с планировкой комнат. Комнаты бывают треугольные, прямоугольные и круглые. Чтобы быстро вычислять жилплощадь, требуется написать программу, на вход которой подаётся тип фигуры комнаты и соответствующие параметры, которая бы выводила площадь получившейся комнаты.
# Для числа π в стране Малевии используют значение 3.14.

# %%
type = str(input())
pi = 3.14
if type == 'треугольник':
  a = int(input())
  b = int(input())
  c = int(input())
  p = (a+b+c)/2
  s = (p*(p-a)*(p-b)*(p-c))**0.5
elif type == 'прямоугольник':
  a = int(input())
  b = int(input())
  s = a*b
elif type == 'круг':
  r = int(input())
  s = pi*(r**2)
else:
  s = "Я не умею считать площадь такой фигуры"
print(s)
# Out:
# фывфыв
# Я не умею считать площадь такой фигуры

# %% [markdown]
# Напишите программу, которая получает на вход три целых числа, по одному числу в строке, и выводит на консоль в три строки сначала максимальное, потом минимальное, после чего оставшееся число.

# %%
# ?max

# %%
# put your python code here
a = int(input())
# Out:
# 2
